# %%
import pandas as pd

# %%
data = pd.read_csv("D:\Docs and Books\Sample CSV FILES\players_19.csv")
data
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33
# ...

# %%
data.tail()
# Out:
#        sofifa_id                                         player_url  \
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#         short_name          long_name  age         dob  height_cm  weight_kg  \
# 17765  P. Phillips    Pierce Phillips   19  1998-09-28        180         72
# 17766   A. Kaltner  Alexander Kaltner   18  1999-10-24        178         75
# 17767  Ma Junliang                马俊亮   20  1998-03-02        181         64
# 17768    C. Ehlich   Christoph Ehlich   19  1999-02-02        179         73
# 17769     E. Tweed         Evan Tweed   19  1999-03-01        180         72
#
#                nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
data.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     193080  https://sofifa.com/player/193080/david-de-gea-...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 6     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 7     177003  https://sofifa.com/player/177003/luka-modric/1...
# 8     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 9     200389  https://sofifa.com/player/200389/jan-oblak/19/...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
# ...

# %%
data.tail(20)
# Out:
#        sofifa_id                                         player_url  \
# 17750     243582  https://sofifa.com/player/243582/shane-griffin...
# 17751     245569  https://sofifa.com/player/245569/lee-watkins/1...
# 17752     238813  https://sofifa.com/player/238813/josh-lundstra...
# 17753     241469  https://sofifa.com/player/241469/tommaso-farab...
# 17754     243901  https://sofifa.com/player/243901/kieron-olsen/...
# 17755     245570  https://sofifa.com/player/245570/jordan-norvil...
# 17756     245862  https://sofifa.com/player/245862/joakim-milli/...
# 17757     240917  https://sofifa.com/player/240917/yufeng-zhang/...
# 17758     244823  https://sofifa.com/player/244823/nicolas-fuent...
# 17759     245571  https://sofifa.com/player/245571/sam-squire/19...
# 17760     231381  https://sofifa.com/player/231381/jordan-young/...
# 17761     240927  https://sofifa.com/player/240927/lewis-collins...
# 17762     234040  https://sofifa.com/player/234040/nathan-sheron...
# ...

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
# Converting or changing the data types
data.sofifa_id.astype('object')
# Out:
# 0         20801
# 1        158023
# 2        190871
# 3        193080
# 4        192985
#           ...
# 17765    238985
# 17766    240160
# 17767    241304
# 17768    240158
# 17769    243961
# Name: sofifa_id, Length: 17770, dtype: object

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
data.dtypes == 'Object'
# Out:
# sofifa_id     False
# player_url    False
# short_name    False
# long_name     False
# age           False
#               ...
# lb            False
# lcb           False
# cb            False
# rcb           False
# rb            False
# Length: 104, dtype: bool

# %%
data.dtypes == "object"
a=data.dtypes[data.dtypes == "object"].index
data.dtypes[a].describe()
# Out:
# count         77
# unique         1
# top       object
# freq          77
# dtype: object

# %%
data.dtypes[data.dtypes == "object"]
# Out:
# player_url     object
# short_name     object
# long_name      object
# dob            object
# nationality    object
#                 ...
# lb             object
# lcb            object
# cb             object
# rcb            object
# rb             object
# Length: 77, dtype: object

# %%
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   17770.000000  17770.000000  17770.000000  17770.000000  17770.000000
# mean   213797.776308     25.193922    181.253292     75.310917     66.240405
# std     29955.746535      4.651957      6.745892      7.080013      6.994104
# min       164.000000     16.000000    154.000000     50.000000     47.000000
# 25%    199803.000000     21.000000    176.000000     70.000000     62.000000
# 50%    221350.500000     25.000000    181.000000     75.000000     66.000000
# 75%    235967.750000     28.000000    186.000000     80.000000     71.000000
# max    246063.000000     45.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  17770.000000  1.777000e+04   17770.000000              17770.000000
# mean      71.382949  2.440756e+06    9956.162071                  1.117783
# ...

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
#Checking for the paticular data types 
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['player_url', 'short_name', 'long_name', 'dob', 'nationality', 'club',
#        'player_positions', 'preferred_foot', 'work_rate', 'body_type',
#        'real_face', 'player_tags', 'team_position', 'loaned_from', 'joined',
#        'nation_position', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
# ...

# %%
#Decribe Data
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   17770.000000  17770.000000  17770.000000  17770.000000  17770.000000
# mean   213797.776308     25.193922    181.253292     75.310917     66.240405
# std     29955.746535      4.651957      6.745892      7.080013      6.994104
# min       164.000000     16.000000    154.000000     50.000000     47.000000
# 25%    199803.000000     21.000000    176.000000     70.000000     62.000000
# 50%    221350.500000     25.000000    181.000000     75.000000     66.000000
# 75%    235967.750000     28.000000    186.000000     80.000000     71.000000
# max    246063.000000     45.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  17770.000000  1.777000e+04   17770.000000              17770.000000
# mean      71.382949  2.440756e+06    9956.162071                  1.117783
# ...

# %%
# Counting the value
data.sofifa_id.count
# Out:
# <bound method Series.count of 0         20801
# 1        158023
# 2        190871
# 3        193080
# 4        192985
#           ...
# 17765    238985
# 17766    240160
# 17767    241304
# 17768    240158
# 17769    243961
# Name: sofifa_id, Length: 17770, dtype: int64>

# %%
list(data.dtpyes == "object")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2572/3178906697.py in <module>
# ----> 1 list(data.dtpyes == "object")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtpyes'

# %%
data.dtypes[data.dtypes == "object"].values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
# ...

# %%
data.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
data[['sofifa_id', 'player_url', 'short_name']]
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name
# 0      Cristiano Ronaldo
# 1               L. Messi
# 2              Neymar Jr
# 3                 De Gea
# ...

# %%
data.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
data.columns_types = ['sofifa_id', 'player_url', 'short_name']
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_2572/886805847.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.columns_types = ['sofifa_id', 'player_url', 'short_name']

# %%
#[Single Bracket represnt series] where as to use it as data frame we need to use [[]]
type(data.dtypes[['sofifa_id', 'player_url', 'short_name']])
# Out:
# pandas.core.series.Series

# %%
type(data[['sofifa_id', 'player_url', 'short_name']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['sofifa_id', 'player_url', 'short_name']][4:100:2]
# Out:
# ['player_url', 'short_name', 'sofifa_id']

# %%
sorted(data['player_url'])
# Out:
# ['https://sofifa.com/player/100899/steve-phillips/19/159222',
#  'https://sofifa.com/player/101317/michael-ratajczak/19/159222',
#  'https://sofifa.com/player/101473/tomasz-kuszczak/19/159222',
#  'https://sofifa.com/player/101488/daniel-haas/19/159222',
#  'https://sofifa.com/player/101880/rob-green/19/159222',
#  'https://sofifa.com/player/102056/simone-padoin/19/159222',
#  'https://sofifa.com/player/102064/claudio-terzi/19/159222',
#  'https://sofifa.com/player/102084/luca-belingheri/19/159222',
#  'https://sofifa.com/player/102593/craig-woodman/19/159222',
#  'https://sofifa.com/player/102881/kyriakos-stamatopoulos/19/159222',
#  'https://sofifa.com/player/104389/rune-almenning-jarstein/19/159222',
#  'https://sofifa.com/player/104442/chris-burke/19/159222',
#  'https://sofifa.com/player/104476/christian-grindheim/19/159222',
#  'https://sofifa.com/player/10466/stefan-ishizaki/19/159222',
#  'https://sofifa.com/player/104702/daniel-braaten/19/159222',
# ...

# %%
data['player_url']
# Out:
# 0        https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1        https://sofifa.com/player/158023/lionel-messi/...
# 2        https://sofifa.com/player/190871/neymar-da-sil...
# 3        https://sofifa.com/player/193080/david-de-gea-...
# 4        https://sofifa.com/player/192985/kevin-de-bruy...
#                                ...
# 17765    https://sofifa.com/player/238985/pierce-philli...
# 17766    https://sofifa.com/player/240160/alexander-kal...
# 17767    https://sofifa.com/player/241304/junliang-ma/1...
# 17768    https://sofifa.com/player/240158/christoph-ehl...
# 17769    https://sofifa.com/player/243961/evan-tweed/19...
# Name: player_url, Length: 17770, dtype: object

# %%
data['sofifa_id'][0:50]
# Out:
# 0      20801
# 1     158023
# 2     190871
# 3     193080
# 4     192985
# 5     155862
# 6     176580
# 7     177003
# 8     183277
# 9     200389
# 10    192119
# 11    167495
# 12    182493
# 13    182521
# 14    188545
# 15    211110
# 16    192448
# 17    197781
# 18    202126
# 19    194765
# 20    215914
# 21    138956
# 22    153079
# 23    168542
# 24    178603
# 25    179813
# 26    190460
# 27    195864
# 28    200145
# 29    189242
# 30    198710
# 31    209331
# 32      1179
# 33    162835
# 34    164240
# 35    167664
# 36    167948
# 37    173731
# 38    176676
# 39    189511
# 40    198219
# 41    231747
# 42    205600
# 43    201024
# 44    201399
# 45    192505
# 46    152729
# 47    168651
# 48    171877
# 49    172871
# Name: sofifa_id, dtype: int64

# %%
# Adding New Column
data['new_columns'] = 'anish'

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33
# ...

# %%
#Adding Column
data['column2']='kumar'

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33
# ...

# %%
pd.Categorical(data["club"])
# Out:
# ['Juventus', 'FC Barcelona', 'Paris Saint-Germain', 'Manchester United', 'Manchester City', ..., 'Cork City', 'SpVgg Unterhaching', 'Guangzhou R&F FC', 'SpVgg Unterhaching', 'Derry City']
# Length: 17770
# Categories (679, object): [' SSV Jahn Regensburg', '1. FC Heidenheim 1846', '1. FC Kaiserslautern', '1. FC Köln', ..., 'Zagłębie Sosnowiec', 'Çaykur Rizespor', 'Örebro SK', 'Östersunds FK']

# %%
# to check categorical data
data.dtypes
# Out:
# sofifa_id       int64
# player_url     object
# short_name     object
# long_name      object
# age             int64
#                 ...
# cb             object
# rcb            object
# rb             object
# new_columns    object
# column2        object
# Length: 106, dtype: object

# %%
pd.Categorical(data["club"],ordered = True)
# Out:
# ['Juventus', 'FC Barcelona', 'Paris Saint-Germain', 'Manchester United', 'Manchester City', ..., 'Cork City', 'SpVgg Unterhaching', 'Guangzhou R&F FC', 'SpVgg Unterhaching', 'Derry City']
# Length: 17770
# Categories (679, object): [' SSV Jahn Regensburg' < '1. FC Heidenheim 1846' < '1. FC Kaiserslautern' < '1. FC Köln' ... 'Zagłębie Sosnowiec' < 'Çaykur Rizespor' < 'Örebro SK' < 'Östersunds FK']

# %%
#Length of any column
data['sofifa_id'].__len__
# Out:
# <bound method Series.__len__ of 0         20801
# 1        158023
# 2        190871
# 3        193080
# 4        192985
#           ...
# 17765    238985
# 17766    240160
# 17767    241304
# 17768    240158
# 17769    243961
# Name: sofifa_id, Length: 17770, dtype: int64>

# %%
data['sififa_id'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sififa_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# To check whihc columns are having null value
data.isnull()
# Out:
#        sofifa_id  player_url  short_name  long_name    age    dob  height_cm  \
# 0          False       False       False      False  False  False      False
# 1          False       False       False      False  False  False      False
# 2          False       False       False      False  False  False      False
# 3          False       False       False      False  False  False      False
# 4          False       False       False      False  False  False      False
# ...          ...         ...         ...        ...    ...    ...        ...
# 17765      False       False       False      False  False  False      False
# 17766      False       False       False      False  False  False      False
# 17767      False       False       False      False  False  False      False
# 17768      False       False       False      False  False  False      False
# 17769      False       False       False      False  False  False      False
#
# ...

# %%
data['age'].isnull().count()
# Out:
# 17770

# %%
data['age'].count()
# Out:
# 17770

# %%
data['age'].notnull().count()
# Out:
# 17770

# %%
# To drop any data / this data will only not shown to us but in real time no data will be removed form the file
data.drop([1])
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# 5         155862  https://sofifa.com/player/155862/sergio-ramos-...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name  age  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33
# ...

# %%
#The columns will not be shown to us in real life it will not be removed formt he our data set 
# To remove data from the sheet we need to remove data from the csv we need to use inplace
data.drop(['age'],axis=1,inplace=True)

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         193080  https://sofifa.com/player/193080/david-de-gea-...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 17765     238985  https://sofifa.com/player/238985/pierce-philli...
# 17766     240160  https://sofifa.com/player/240160/alexander-kal...
# 17767     241304  https://sofifa.com/player/241304/junliang-ma/1...
# 17768     240158  https://sofifa.com/player/240158/christoph-ehl...
# 17769     243961  https://sofifa.com/player/243961/evan-tweed/19...
#
#               short_name                            long_name         dob  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  1985-02-05
# ...

# %%
data['dob'][data.dob.isnull()].index
# Out:
# Int64Index([], dtype='int64')
