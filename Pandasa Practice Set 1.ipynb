# %%
import pandas as pd
titanic_data = pd.read_csv("D:\Docs and Books\Sample CSV FILES\snakes_count_1000.csv",
                           sep="\t")
titanic_data
# Out:
#     GameNumber, GameLength
# 0                     1,30
# 1                     2,29
# 2                     3,31
# 3                     4,16
# 4                     5,24
# ..                     ...
# 995                 996,24
# 996                 997,21
# 997                 998,47
# 998                 999,30
# 999                1000,12
#
# [1000 rows x 1 columns]

# %%
titanic_data.head()
# Out:
#   Game Number, "Game Length"
# 0                      1, 30
# 1                      2, 29
# 2                      3, 31
# 3                      4, 16
# 4                      5, 24

# %%
type(titanic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data
# Out:
#     Game Number, "Game Length"
# 0                        1, 30
# 1                        2, 29
# 2                        3, 31
# 3                        4, 16
# 4                        5, 24
# ..                         ...
# 995                    996, 24
# 996                    997, 21
# 997                    998, 47
# 998                    999, 30
# 999                   1000, 12
#
# [1000 rows x 1 columns]

# %%
# Each column is consider as series in Pandas
type(titanic_data.dtypes)
# Out:
# pandas.core.series.Series

# %%
dy = titanic_data.dtypes

# %%
type(dy)
# Out:
# pandas.core.series.Series

# %%
titanic_data
# Out:
#     Game Number, "Game Length"
# 0                        1, 30
# 1                        2, 29
# 2                        3, 31
# 3                        4, 16
# 4                        5, 24
# ..                         ...
# 995                    996, 24
# 996                    997, 21
# 997                    998, 47
# 998                    999, 30
# 999                   1000, 12
#
# [1000 rows x 1 columns]

# %%
titanic_data[GameNumber]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4520/3054793127.py in <module>
# ----> 1 titanic_data[GameNumber]
#
# NameError: name 'GameNumber' is not defined

# %%
t1 = titanic_data.dtypes

# %%
t1
# Out:
# Game Number, "Game Length"    object
# dtype: object

# %%
#data Manupulation 
titanic_data[0:10:2]
# Out:
#   Game Number, "Game Length"
# 0                      1, 30
# 2                      3, 31
# 4                      5, 24
# 6                      7, 28
# 8                      9, 42

# %%
titanic_data['Game Length']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Game Length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic_data.describe()
# Out:
#        Game Number, "Game Length"
# count                        1000
# unique                       1000
# top                         1, 30
# freq                            1

# %%
titanic_data.describe()
# Out:
#        GameNumber, GameLength
# count                    1000
# unique                   1000
# top                      1,30
# freq                        1

# %%
titanic_data['GameNumber']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GameNumber'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(titanic_data[[][0:1000:10]])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data.describe()
# Out:
#        GameNumber, GameLength
# count                    1000
# unique                   1000
# top                      1,30
# freq                        1

# %%
titanic_data.dtypes
# Out:
# GameNumber, GameLength    object
# dtype: object

# %%
titanic_data[['GameLength']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4520/1539563569.py in <module>
# ----> 1 titanic_data[['GameLength']]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ...

# %%
d2 = pd.read_csv("D:\Docs and Books\Sample CSV FILES\ConsumerReportsNaughtyNiceList.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4520/3345278035.py in <module>
# ----> 1 d2 = pd.read_csv("D:\Docs and Books\Sample CSV FILES\ConsumerReportsNaughtyNiceList.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import numpy as np

# %%
testData = np.where(titanic_data[0:100:2].isNull() == False)
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp/ipykernel_4520/82561294.py", line 1
#     testData = np.where(titanic_data[][0:100:2].isNull() == False)
#                                      ^
# SyntaxError: invalid syntax

# %%
testData = np.where(titanic_data['GameLength'].isNUll()==True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GameLength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
testData=[titanic_data['GameLength'].isnull() == True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GameLength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
testData = np.where(titanic_data['GameLength']==23)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GameLength'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
te2=[titanic_data[0:100:2]==25]

# %%
te2
# Out:
# [    GameNumber, GameLength
#  0                    False
#  2                    False
#  4                    False
#  6                    False
#  8                    False
#  10                   False
#  12                   False
#  14                   False
#  16                   False
#  18                   False
#  20                   False
#  22                   False
#  24                   False
#  26                   False
#  28                   False
#  30                   False
#  32                   False
#  34                   False
#  36                   False
#  38                   False
#  40                   False
#  42                   False
#  44                   False
#  46                   False
#  48                   False
#  50                   False
#  52                   False
#  54                   False
#  56                   False
#  58                   False
#  60                   False
#  62                   False
# ...

# %%
import pandas as pd

# %%
player = pd.read_csv('D:\Docs and Books\Sample CSV FILES\players_15.csv')

# %%
player
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
player['long_name']
# Out:
# 0             Lionel Andrés Messi Cuccittini
# 1        Cristiano Ronaldo dos Santos Aveiro
# 2                               Arjen Robben
# 3                         Zlatan Ibrahimović
# 4                               Manuel Neuer
#                         ...
# 15460                           Ellis Redman
# 15461                          Aaron Collins
# 15462                            Piotr Żemło
# 15463                             Tom Davies
# 15464                           Paul Tisdale
# Name: long_name, Length: 15465, dtype: object

# %%
player.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %%
player.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   15465.000000  15465.000000  15465.000000  15465.000000  15465.000000
# mean   189298.588425     24.763272    181.093631     75.482703     63.948594
# std     39648.820272      4.624565      6.635182      6.907243      7.208610
# min         2.000000     16.000000    155.000000     50.000000     40.000000
# 25%    178043.000000     21.000000    176.000000     70.000000     59.000000
# 50%    200844.000000     24.000000    181.000000     75.000000     64.000000
# 75%    214326.000000     28.000000    186.000000     80.000000     69.000000
# max    225562.000000     44.000000    203.000000    110.000000     93.000000
#
#           potential  value_eur  wage_eur  international_reputation  \
# count  15465.000000    15465.0   15465.0              15465.000000
# mean      68.483091        0.0       0.0                  1.126350
# std        6.611708        0.0       0.0                  0.401362
# ...

# %%
import numpy as np

# %%
t1 = np.where(player['mentality_composure']=='NaN')

# %%
t1
# Out:
# (array([], dtype=int64),)

# %%
t2 = player['overall']>=60

# %%
t2
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 15460    False
# 15461    False
# 15462    False
# 15463    False
# 15464    False
# Name: overall, Length: 15465, dtype: bool

# %%
# &operator with 
player[(player['weight_kg']>=75) & (player['height_cm']>=170)]
# Out:
#        sofifa_id                                         player_url  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 15455      11728  https://sofifa.com/player/11728/barry-richards...
# 15456     211228  https://sofifa.com/player/211228/matthew-palme...
# 15459     214725  https://sofifa.com/player/214725/sam-ramsbotto...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
#
#               short_name                            long_name  age  \
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# ...

# %%
player.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   15465.000000  15465.000000  15465.000000  15465.000000  15465.000000
# mean   189298.588425     24.763272    181.093631     75.482703     63.948594
# std     39648.820272      4.624565      6.635182      6.907243      7.208610
# min         2.000000     16.000000    155.000000     50.000000     40.000000
# 25%    178043.000000     21.000000    176.000000     70.000000     59.000000
# 50%    200844.000000     24.000000    181.000000     75.000000     64.000000
# 75%    214326.000000     28.000000    186.000000     80.000000     69.000000
# max    225562.000000     44.000000    203.000000    110.000000     93.000000
#
#           potential  value_eur  wage_eur  international_reputation  \
# count  15465.000000    15465.0   15465.0              15465.000000
# mean      68.483091        0.0       0.0                  1.126350
# std        6.611708        0.0       0.0                  0.401362
# ...

# %%
t3=player[(player['age']>=24) & (player['weight_kg']>=75) & (player['height_cm']>=180)]

# %%
t3
# Out:
#        sofifa_id                                         player_url  \
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 15283     199068  https://sofifa.com/player/199068/ashley-bayes/...
# 15339     211659  https://sofifa.com/player/211659/ho-yeon-cho/1...
# 15405     221917  https://sofifa.com/player/221917/simon-manzoni...
# 15454     194372  https://sofifa.com/player/194372/mahmut-ertugr...
# 15455      11728  https://sofifa.com/player/11728/barry-richards...
#
#               short_name                            long_name  age  \
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# ...

# %%
import numpy as np

# %%
t4 = np.where(player['weight_kg']>=80)

# %%
t4
# Out:
# (array([    1,     2,     3, ..., 15454, 15459, 15460], dtype=int64),)

# %%
print(t4)
# Out:
# (array([    1,     2,     3, ..., 15454, 15459, 15460], dtype=int64),)
